# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x_axis = [1,2,3] #https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
y_axis = [4,5,6]
plt.plot(x_axis,y_axis,'k') # here k is the color character

# %%
x_axis = [1,2,3]
y_axis = [4,5,6]
plt.title('Tans Line Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.plot(x_axis,y_axis,'r')

# %%
x1_axis = [1,2,3]  #for multiple line
x2_axis = [4,5,6]
y1_axis = [10,21,31]
y2_axis = [71,81,90]
plt.title('Tans Line Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.plot(x1_axis,y1_axis,'r')
plt.plot(x2_axis,y2_axis,'b')

# %%
x1_axis = [1,2,3]  #for multiple line
x2_axis = [4,5,6]
y1_axis = [10,21,31]
y2_axis = [71,81,90]
plt.title('Tans Line Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.plot(x1_axis,y1_axis,'r')
plt.plot(x2_axis,y2_axis,'b')
plt.legend(['Line1','Line2'])

# %%
x1_axis = [10,21,31]
plt.hist(x1_axis, color ='g',  width = 0.5)
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
values =[5,10,15]
plt.bar(values,[0.5,1.5,2], width=2)
# Out:
# <BarContainer object of 3 artists>

# %%
values =[5,10,15,20,25]
plt.pie(values,labels=['A','B','C','D','E'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7dc264baf4d0>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, 'A'),
#   Text(0.7360436312779136, 0.817459340184711, 'B'),
#   Text(-0.33991877217145816, 1.046162142464278, 'C'),
#   Text(-1.0759623315431446, -0.2287029975759841, 'D'),
#   Text(0.5500001932481627, -0.9526278325909778, 'E')])

# %%
values =[5,10,15,20,25]
plt.pie(values,labels=['A','B','C','D','E'], explode=[0.1,0,0,0.1,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x7dc264924a10>,
# ...
#  [Text(1.1737771181553132, 0.24949404180262147, 'A'),
#   Text(0.7360436312779136, 0.817459340184711, 'B'),
#   Text(-0.33991877217145816, 1.046162142464278, 'C'),
#   Text(-1.1737770889561576, -0.24949417917380085, 'D'),
#   Text(0.5500001932481627, -0.9526278325909778, 'E')])

# %%
values =[5,10,15,20,25]
plt.pie(values,labels=['A','B','C','D','E'], explode=[0.1,0,0,0.1,0], colors=['red','green','blue','yellow','orange'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7dc26499b250>,
# ...
#  [Text(1.1737771181553132, 0.24949404180262147, 'A'),
#   Text(0.7360436312779136, 0.817459340184711, 'B'),
#   Text(-0.33991877217145816, 1.046162142464278, 'C'),
#   Text(-1.1737770889561576, -0.24949417917380085, 'D'),
#   Text(0.5500001932481627, -0.9526278325909778, 'E')])

# %%
x1_axis = [1,2,3,71,81,90]
x2_axis = [4,5,6,10,21,31]
plt.title('Scatter Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.scatter(x1_axis,x2_axis,color='r')

# %%
x1_axis = [1,2,3,71,81,90]
x2_axis = [4,5,6,10,21,31]
plt.title('Scatter Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.scatter(x1_axis,x2_axis, c=[1,2,3,4,5,6]) #for different color

# %%
x1_axis = [1,2,3,71,81,90]
x2_axis = [4,5,6,10,21,31]
plt.title('Scatter Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.scatter(x1_axis,x2_axis, c=[1,2,3,4,5,6], cmap='Accent') #for colormap in sequence

# %%
from matplotlib import cm

# %%
dir(cm) # for showing values
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'ColormapRegistry',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Grays',
#  'Grays_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'Mapping',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
# ...

# %%
x_axis = [1,2,3,71,81,90]
y_axis = [4,5,6,10,21,31]
plt.yscale('log')
plt.plot(x_axis, y_axis)

# %%
theta = np.arange(0,(2*np.pi),0.01)
r = 2
for radian in theta:
  plt.polar(radian,r)

# %%
Dates = ['16-01-2025','17-01-2025','18-01-2025','19-01-2025','20-01-2025','21-01-2025','22-01-2025','23-01-2025']
values = [1,2,3,4,5,6,7,8]
plt.xticks(rotation=90) #Rotation
plt.plot(Dates,values)

# %%
x1_axis = [1,2,3]  #for multiple line
x2_axis = [4,5,6]
y1_axis = [10,21,31]
y2_axis = [71,81,90]
plt.subplot(1,2,1)
plt.plot(x1_axis,y1_axis,'r')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Line1')
plt.subplot(1,2,2)
plt.plot(x2_axis,y2_axis,'b')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line2')
plt.tight_layout()
