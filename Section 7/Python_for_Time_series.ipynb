# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Install yfinance
# !pip install yfinance

# %%
tf = yf.download('AAPL', start='2022-01-01', end='2022-01-31')
tf.head(10)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2022-01-03  178.879929  179.734977  174.653889  174.771820  104487900
# 2022-01-04  176.609650  179.793936  176.039622  179.489269   99310400
# 2022-01-05  171.911880  177.071596  171.636697  176.521228   94537600
# 2022-01-06  169.042068  172.285320  168.688259  169.730027   96904000
# 2022-01-07  169.209152  171.145275  168.088758  169.916771   86709100
# 2022-01-10  169.228790  169.533457  165.277919  166.172273  106765600
# 2022-01-11  172.069107  172.167378  167.882373  169.356577   76138300
# 2022-01-12  172.511383  174.133002  171.813601  173.091233   74805200
# 2022-01-13  169.228790  173.582599  168.835660  172.757048   84505800
# ...

# %%
tf.index = pd.to_datetime(tf.index, format = '%d-%m-%Y %I-%p') #for time %I-%p(am/pm)
tf
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2022-01-03  178.879929  179.734977  174.653889  174.771820  104487900
# 2022-01-04  176.609650  179.793936  176.039622  179.489269   99310400
# 2022-01-05  171.911880  177.071596  171.636697  176.521228   94537600
# 2022-01-06  169.042068  172.285320  168.688259  169.730027   96904000
# 2022-01-07  169.209152  171.145275  168.088758  169.916771   86709100
# 2022-01-10  169.228790  169.533457  165.277919  166.172273  106765600
# 2022-01-11  172.069107  172.167378  167.882373  169.356577   76138300
# 2022-01-12  172.511383  174.133002  171.813601  173.091233   74805200
# 2022-01-13  169.228790  173.582599  168.835660  172.757048   84505800
# 2022-01-14  170.093658  170.791440  168.147698  168.393399   80440800
# 2022-01-18  166.879898  169.572768  166.496606  168.560482   90956700
# ...

# %%
jan1 = pd.to_datetime('2022-01-01')
jan1.day_name()
# Out:
# 'Saturday'

# %%
tf.loc['2022-01-01' : '2022-01-05']
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2022-01-03  178.879929  179.734977  174.653889  174.771820  104487900
# 2022-01-04  176.609650  179.793936  176.039622  179.489269   99310400
# 2022-01-05  171.911880  177.071596  171.636697  176.521228   94537600

# %%
plt.figure(figsize=(10,5))
plt.title('Apple Stock Price')
plt.xlabel('Year')
plt.ylabel('Price')
plt.plot(tf['Close'])

# %%
plt.figure(figsize=(10,5))
plt.title('Apple Stock Price')
plt.xlabel('Year')
plt.ylabel('Price')
plt.plot(tf.loc['2022']['Close'])
