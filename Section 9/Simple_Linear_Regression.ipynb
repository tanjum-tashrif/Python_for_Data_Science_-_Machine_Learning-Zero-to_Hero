# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/drive/MyDrive/Diabetes/diabetes_dataset.csv')
df
# Out:
#        Age  Gender Ethnicity  ...  Stress_Level  Medication_Use  Diabetes_Diagnosis
# 0       69  Female     Other  ...           Low               0                   1
# 1       32    Male     Black  ...           Low               1                   0
# 2       89    Male     White  ...          High               1                   0
# 3       78    Male     Other  ...           Low               1                   1
# 4       38  Female     White  ...          High               1                   0
# ...    ...     ...       ...  ...           ...             ...                 ...
# 49995   21    Male     Black  ...      Moderate               0                   1
# 49996   35  Female     Asian  ...      Moderate               0                   1
# 49997   46    Male     White  ...      Moderate               1                   0
# 49998   56    Male     Other  ...          High               0                   0
# ...

# %%
plt.xlabel('Age')
plt.ylabel('HbA1c')
plt.scatter(df.Age, df.HbA1c, color='red', marker='+')

# %%
reg = LinearRegression()
reg.fit(df[['Age']], df.HbA1c)
# Out:
# LinearRegression()

# %%
reg.predict([[25]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7.0027567])

# %%
reg.coef_
# Out:
# array([-0.00012651])

# %%
reg.intercept_
# Out:
# 7.005919435416295
