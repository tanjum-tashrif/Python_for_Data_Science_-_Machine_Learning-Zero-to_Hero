# %%
import pandas  as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mylist =[['Jackfruit','Green'],['Orange','Orange'],['Banana','Red']]
df = pd.DataFrame(mylist)
df
# Out:
#            0       1
# 0  Jackfruit   Green
# 1     Orange  Orange
# 2     Banana     Red

# %%
heading= pd.DataFrame(mylist,columns=['Fruits','Colors'])
heading
# Out:
#       Fruits  Colors
# 0  Jackfruit   Green
# 1     Orange  Orange
# 2     Banana     Red

# %%
nplist=np.array([[1,2],[3,4],[5,6]])
DF =pd.DataFrame(nplist)
DF
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6

# %%
Df=pd.DataFrame(nplist,columns=['ODD','EVEN'])
Df
# Out:
#    ODD  EVEN
# 0    1     2
# 1    3     4
# 2    5     6

# %%
fruitlist ={'Fruits':['Banana','Orange','Mango'],'Colors':['Yellow','Orange','Green']} #from dictionaries
output=pd.DataFrame(fruitlist)
output
# Out:
#    Fruits  Colors
# 0  Banana  Yellow
# 1  Orange  Orange
# 2   Mango   Green

# %%
Data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/students_data.csv')
Data
# Out:
#     Student_ID  Age  Gender  Math_Score  English_Score  Science_Score  \
# 0        S0358   18    Male          36              2             69
# 1        S0260   19  Female          93              9             12
# 2        S0358   18    Male          36              2             69
# 3        S0194   20    Male          72             63             64
# 4        S0334   21  Female           9             21             39
# ..         ...  ...     ...         ...            ...            ...
# 760      S0072   24    Male           5             97             62
# 761      S0107   22    Male          63             49             71
# 762      S0271   22  Female          59             49             84
# 763      S0436   18  Female          18            100             90
# 764      S0103   21    Male          49              9             45
#
#      Attendance  Study_Hours  Passed Irrelevant_Col_1  ... Irrelevant_Col_21  \
# ...

# %%
cngindex=Data.set_index('Student_ID') #Changes of Index
cngindex
# Out:
#             Age  Gender  Math_Score  English_Score  Science_Score  Attendance  \
# Student_ID
# S0358        18    Male          36              2             69   92.826861
# S0260        19  Female          93              9             12   75.834919
# S0358        18    Male          36              2             69   92.826861
# S0194        20    Male          72             63             64   89.629756
# S0334        21  Female           9             21             39   63.266307
# ...         ...     ...         ...            ...            ...         ...
# S0072        24    Male           5             97             62   55.575611
# S0107        22    Male          63             49             71   68.586965
# S0271        22  Female          59             49             84   60.234005
# S0436        18  Female          18            100             90   55.665175
# S0103        21    Male          49              9             45   64.665431
#
# ...

# %%
Data.set_index('Student_ID',inplace=True)  #Change permanantly using inplace
Data
# Out:
#             Age  Gender  Math_Score  English_Score  Science_Score  Attendance  \
# Student_ID
# S0358        18    Male          36              2             69   92.826861
# S0260        19  Female          93              9             12   75.834919
# S0358        18    Male          36              2             69   92.826861
# S0194        20    Male          72             63             64   89.629756
# S0334        21  Female           9             21             39   63.266307
# ...         ...     ...         ...            ...            ...         ...
# S0072        24    Male           5             97             62   55.575611
# S0107        22    Male          63             49             71   68.586965
# S0271        22  Female          59             49             84   60.234005
# S0436        18  Female          18            100             90   55.665175
# S0103        21    Male          49              9             45   64.665431
#
# ...

# %%
Data.describe()   #Statistical Summary
# Out:
#               Age  Math_Score  English_Score  Science_Score  Attendance  \
# count  765.000000  765.000000     765.000000     765.000000  765.000000
# mean    20.962092   48.464052      48.266667      49.454902   74.824704
# std      2.007154   29.128041      29.951741      28.152718   14.457811
# min     18.000000    0.000000       0.000000       0.000000   50.000582
# 25%     19.000000   23.000000      21.000000      26.000000   62.418813
# 50%     21.000000   46.000000      48.000000      48.000000   75.020057
# 75%     23.000000   74.000000      74.000000      73.000000   87.094816
# max     24.000000  100.000000     100.000000     100.000000   99.859118
#
#        Study_Hours      Passed
# count   732.000000  765.000000
# mean      4.930000    0.586928
# std       2.911981    0.492708
# min       0.060000    0.000000
# 25%       2.362500    0.000000
# 50%       4.805000    1.000000
# 75%       7.525000    1.000000
# max      10.000000    1.000000

# %%
Data[0:4]
# Out:
#             Age  Gender  Math_Score  English_Score  Science_Score  Attendance  \
# Student_ID
# S0358        18    Male          36              2             69   92.826861
# S0260        19  Female          93              9             12   75.834919
# S0358        18    Male          36              2             69   92.826861
# S0194        20    Male          72             63             64   89.629756
#
#             Study_Hours  Passed Irrelevant_Col_1 Irrelevant_Col_2  ...  \
# Student_ID                                                         ...
# S0358              9.90       1                A                C  ...
# S0260              5.57       0                B              NaN  ...
# S0358              9.90       1                A                C  ...
# S0194              8.04       0              NaN                A  ...
#
#            Irrelevant_Col_21 Irrelevant_Col_22 Irrelevant_Col_23  \
# Student_ID
# ...

# %%
Data[['Age','Gender']]
# Out:
#             Age  Gender
# Student_ID
# S0358        18    Male
# S0260        19  Female
# S0358        18    Male
# S0194        20    Male
# S0334        21  Female
# ...         ...     ...
# S0072        24    Male
# S0107        22    Male
# S0271        22  Female
# S0436        18  Female
# S0103        21    Male
#
# [765 rows x 2 columns]

# %%
#Boolean List
bol = Data[0:4]
bol
# Out:
#             Age  Gender  Math_Score  English_Score  Science_Score  Attendance  \
# Student_ID
# S0358        18    Male          36              2             69   92.826861
# S0260        19  Female          93              9             12   75.834919
# S0358        18    Male          36              2             69   92.826861
# S0194        20    Male          72             63             64   89.629756
#
#             Study_Hours  Passed Irrelevant_Col_1 Irrelevant_Col_2  ...  \
# Student_ID                                                         ...
# S0358              9.90       1                A                C  ...
# S0260              5.57       0                B              NaN  ...
# S0358              9.90       1                A                C  ...
# S0194              8.04       0              NaN                A  ...
#
#            Irrelevant_Col_21 Irrelevant_Col_22 Irrelevant_Col_23  \
# Student_ID
# ...

# %%
Thirdrow = [True, False, True, False]
bol[Thirdrow]
# Out:
#             Age Gender  Math_Score  English_Score  Science_Score  Attendance  \
# Student_ID
# S0358        18   Male          36              2             69   92.826861
# S0358        18   Male          36              2             69   92.826861
#
#             Study_Hours  Passed Irrelevant_Col_1 Irrelevant_Col_2  ...  \
# Student_ID                                                         ...
# S0358               9.9       1                A                C  ...
# S0358               9.9       1                A                C  ...
#
#            Irrelevant_Col_21 Irrelevant_Col_22 Irrelevant_Col_23  \
# Student_ID
# S0358                      A               NaN               NaN
# S0358                      A               NaN               NaN
#
#            Irrelevant_Col_24 Irrelevant_Col_25 Irrelevant_Col_26  \
# Student_ID
# S0358                      C                 A                 C
# S0358                      C                 A                 C
#
# ...

# %%
#filter any data
condition=Data['English_Score'] ==100
Data[condition]
# Out:
#             Age  Gender  Math_Score  English_Score  Science_Score  Attendance  \
# Student_ID
# S0228        20    Male          54            100             65   69.891831
# S0722        22    Male          83            100             49   57.016226
# S0725        24    Male          29            100             23   87.112659
# S0136        19  Female          71            100             46   59.791654
# S0146        24    Male          44            100             63   62.995249
# S0168        20    Male          39            100             61   77.328857
# S0366        22    Male          19            100             39   89.310283
# S0020        21    Male          63            100             72   54.464476
# S0408        18  Female          84            100             47   81.064622
# S0128        20  Female          85            100             27   97.136216
# S0697        18    Male          34            100             29   66.058108
# ...

# %%
Data[(Data['English_Score'] ==100) & (Data['Math_Score']>84)]
# Out:
#             Age  Gender  Math_Score  English_Score  Science_Score  Attendance  \
# Student_ID
# S0128        20  Female          85            100             27   97.136216
#
#             Study_Hours  Passed Irrelevant_Col_1 Irrelevant_Col_2  ...  \
# Student_ID                                                         ...
# S0128              5.83       0                C                B  ...
#
#            Irrelevant_Col_21 Irrelevant_Col_22 Irrelevant_Col_23  \
# Student_ID
# S0128                      A                 B                 C
#
#            Irrelevant_Col_24 Irrelevant_Col_25 Irrelevant_Col_26  \
# Student_ID
# S0128                    NaN                 B               NaN
#
#            Irrelevant_Col_27 Irrelevant_Col_28 Irrelevant_Col_29  \
# Student_ID
# S0128                      B                 A                 B
#
#            Irrelevant_Col_30
# Student_ID
# S0128                    NaN
#
# [1 rows x 38 columns]

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data Book.csv')
data
# Out:
#      year  month Sylhet  Janta Hills  Karimgoang  Haliakndi  \
# 0    1955      1    170        6.542       1.624      1.474
# 1    1955      2    155       15.329       6.926      8.295
# 2    1955      3    170      200.806     165.000    214.891
# 3    1955      4    190      246.243     135.765    120.697
# 4    1955      5    230      522.916     363.777    372.848
# ..    ...    ...    ...          ...         ...        ...
# 823  2023      8    NaN          NaN         NaN        NaN
# 824  2023      9    NaN          NaN         NaN        NaN
# 825  2023     10    NaN          NaN         NaN        NaN
# 826  2023     11    NaN          NaN         NaN        NaN
# 827  2023     12    NaN          NaN         NaN        NaN
#
#      NorthChacherHills   cacher Cherapunji  Shurma  flood
# 0                4.579    2.277       16.8     7.5    0.0
# 1               16.821   11.539       23.9     7.0    0.0
# 2              254.779  235.586      383.5     7.5    0.0
# ...

# %%
# loc
data.loc[[0], ['Sylhet']]
# Out:
#   Sylhet
# 0    170

# %%
data.loc[5:9, 'year':'Sylhet']
# Out:
#    year  month Sylhet
# 5  1955      0      0
# 6  1955      7    550
# 7  1955      8    800
# 8  1955      9    250
# 9  1955     10    200

# %%
data.iloc[0:3,0:4] # iloc used  to slice both rows and column at a time
# Out:
#    year  month Sylhet  Janta Hills
# 0  1955      1    170        6.542
# 1  1955      2    155       15.329
# 2  1955      3    170      200.806

# %%
#adding or deleting
data.drop(columns=['Sylhet'])
# Out:
#      year  month  Janta Hills  Karimgoang  Haliakndi  NorthChacherHills  \
# 0    1955      1        6.542       1.624      1.474              4.579
# 1    1955      2       15.329       6.926      8.295             16.821
# 2    1955      3      200.806     165.000    214.891            254.779
# 3    1955      4      246.243     135.765    120.697            178.565
# 4    1955      5      522.916     363.777    372.848            451.579
# ..    ...    ...          ...         ...        ...                ...
# 823  2023      8          NaN         NaN        NaN                NaN
# 824  2023      9          NaN         NaN        NaN                NaN
# 825  2023     10          NaN         NaN        NaN                NaN
# 826  2023     11          NaN         NaN        NaN                NaN
# 827  2023     12          NaN         NaN        NaN                NaN
#
#       cacher Cherapunji  Shurma  flood
# 0      2.277       16.8     7.5    0.0
# ...

# %%
data.drop(2, axis=0,inplace=True)
data
# Out:
#      year  month Sylhet  Janta Hills  Karimgoang  Haliakndi  \
# 0    1955      1    170        6.542       1.624      1.474
# 1    1955      2    155       15.329       6.926      8.295
# 3    1955      4    190      246.243     135.765    120.697
# 4    1955      5    230      522.916     363.777    372.848
# 5    1955      0      0        0.000       0.000      0.000
# ..    ...    ...    ...          ...         ...        ...
# 823  2023      8    NaN          NaN         NaN        NaN
# 824  2023      9    NaN          NaN         NaN        NaN
# 825  2023     10    NaN          NaN         NaN        NaN
# 826  2023     11    NaN          NaN         NaN        NaN
# 827  2023     12    NaN          NaN         NaN        NaN
#
#      NorthChacherHills   cacher Cherapunji  Shurma  flood
# 0                4.579    2.277       16.8     7.5    0.0
# 1               16.821   11.539       23.9     7.0    0.0
# 3              178.565  140.615      707.1     8.0    0.0
# ...

# %%
data.loc[4]=[2025,1,123,12,34,53,42,252,2525,25,25]
data
# Out:
#      year  month Sylhet  Janta Hills  Karimgoang  Haliakndi  \
# 0    1955      1    170        6.542       1.624      1.474
# 1    1955      2    155       15.329       6.926      8.295
# 3    1955      4    190      246.243     135.765    120.697
# 4    2025      1    123       12.000      34.000     53.000
# 5    1955      0      0        0.000       0.000      0.000
# ..    ...    ...    ...          ...         ...        ...
# 823  2023      8    NaN          NaN         NaN        NaN
# 824  2023      9    NaN          NaN         NaN        NaN
# 825  2023     10    NaN          NaN         NaN        NaN
# 826  2023     11    NaN          NaN         NaN        NaN
# 827  2023     12    NaN          NaN         NaN        NaN
#
#      NorthChacherHills   cacher Cherapunji  Shurma  flood
# 0                4.579    2.277       16.8     7.5    0.0
# 1               16.821   11.539       23.9     7.0    0.0
# 3              178.565  140.615      707.1     8.0    0.0
# ...

# %%
data = data[0:4]
data
# Out:
#    year  month Sylhet  Janta Hills  Karimgoang  Haliakndi  NorthChacherHills  \
# 0  1955      1    170        6.542       1.624      1.474              4.579
# 1  1955      2    155       15.329       6.926      8.295             16.821
# 3  1955      4    190      246.243     135.765    120.697            178.565
# 4  2025      1    123       12.000      34.000     53.000             42.000
#
#     cacher Cherapunji  Shurma  flood
# 0    2.277       16.8     7.5    0.0
# 1   11.539       23.9     7.0    0.0
# 3  140.615      707.1     8.0    0.0
# 4  252.000       2525    25.0   25.0

# %%
data['Tanjum']=['A','B','c','d']
data
# Out:
# <ipython-input-26-d00fa87d6d8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Tanjum']=['A','B','c','d']
#    year  month Sylhet  Janta Hills  Karimgoang  Haliakndi  NorthChacherHills  \
# 0  1955      1    170        6.542       1.624      1.474              4.579
# 1  1955      2    155       15.329       6.926      8.295             16.821
# 3  1955      4    190      246.243     135.765    120.697            178.565
# 4  2025      1    123       12.000      34.000     53.000             42.000
#
#     cacher Cherapunji  Shurma  flood Tanjum
# 0    2.277       16.8     7.5    0.0      A
# 1   11.539       23.9     7.0    0.0      B
# 3  140.615      707.1     8.0    0.0      c
# 4  252.000       2525    25.0   25.0      d

# %%
data.sort_values('month')
# Out:
#    year  month Sylhet  Janta Hills  Karimgoang  Haliakndi  NorthChacherHills  \
# 0  1955      1    170        6.542       1.624      1.474              4.579
# 4  2025      1    123       12.000      34.000     53.000             42.000
# 1  1955      2    155       15.329       6.926      8.295             16.821
# 3  1955      4    190      246.243     135.765    120.697            178.565
#
#     cacher Cherapunji  Shurma  flood Tanjum
# 0    2.277       16.8     7.5    0.0      A
# 4  252.000       2525    25.0   25.0      d
# 1   11.539       23.9     7.0    0.0      B
# 3  140.615      707.1     8.0    0.0      c

# %%
data.sort_values('month',ascending=False,inplace=True)
data
# Out:
# <ipython-input-28-059f705d502a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.sort_values('month',ascending=False,inplace=True)
#    year  month Sylhet  Janta Hills  Karimgoang  Haliakndi  NorthChacherHills  \
# 3  1955      4    190      246.243     135.765    120.697            178.565
# 1  1955      2    155       15.329       6.926      8.295             16.821
# 0  1955      1    170        6.542       1.624      1.474              4.579
# 4  2025      1    123       12.000      34.000     53.000             42.000
#
#     cacher Cherapunji  Shurma  flood Tanjum
# 3  140.615      707.1     8.0    0.0      c
# 1   11.539       23.9     7.0    0.0      B
# 0    2.277       16.8     7.5    0.0      A
# 4  252.000       2525    25.0   25.0      d

# %%
concat= pd.concat([Data,data]) #concatinatetwo dataset
concat
# Out:
#         Age  Gender  Math_Score  English_Score  Science_Score  Attendance  \
# S0358  18.0    Male        36.0            2.0           69.0   92.826861
# S0260  19.0  Female        93.0            9.0           12.0   75.834919
# S0358  18.0    Male        36.0            2.0           69.0   92.826861
# S0194  20.0    Male        72.0           63.0           64.0   89.629756
# S0334  21.0  Female         9.0           21.0           39.0   63.266307
# ...     ...     ...         ...            ...            ...         ...
# S0103  21.0    Male        49.0            9.0           45.0   64.665431
# 3       NaN     NaN         NaN            NaN            NaN         NaN
# 1       NaN     NaN         NaN            NaN            NaN         NaN
# 0       NaN     NaN         NaN            NaN            NaN         NaN
# 4       NaN     NaN         NaN            NaN            NaN         NaN
#
#        Study_Hours  Passed Irrelevant_Col_1 Irrelevant_Col_2  ... Sylhet  \
# ...

# %%
data['year'] = pd.to_numeric(data['year'], errors='coerce')

data
# Out:
# <ipython-input-30-3afe837aeaec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year'] = pd.to_numeric(data['year'], errors='coerce')
#    year  month Sylhet  Janta Hills  Karimgoang  Haliakndi  NorthChacherHills  \
# 3  1955      4    190      246.243     135.765    120.697            178.565
# 1  1955      2    155       15.329       6.926      8.295             16.821
# 0  1955      1    170        6.542       1.624      1.474              4.579
# 4  2025      1    123       12.000      34.000     53.000             42.000
#
#     cacher Cherapunji  Shurma  flood Tanjum
# 3  140.615      707.1     8.0    0.0      c
# 1   11.539       23.9     7.0    0.0      B
# 0    2.277       16.8     7.5    0.0      A
# ...
